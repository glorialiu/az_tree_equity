# %%
from keplergl import KeplerGl
import geopandas
import json

# %%
az_gjson = geopandas.read_file("merged.geojson")

# %%
config = {
    "version": "v1",
    "config":
    {
        "visState":
        {
            "filters":
            [],
            "layers":
            [
                {
                    "id": "rtbxsn",
                    "type": "point",
                    "config":
                    {
                        "dataId": "30tsioqw",
                        "label": "intpt",
                        "color":
                        [
                            255,
                            203,
                            153
                        ],
                        "highlightColor":
                        [
                            252,
                            242,
                            26,
                            255
                        ],
                        "columns":
                        {
                            "lat": "INTPTLAT",
                            "lng": "INTPTLON",
                            "altitude": None
                        },
                        "isVisible": False,
                        "visConfig":
                        {
                            "radius": 10,
                            "fixedRadius": False,
                            "opacity": 0.8,
                            "outline": False,
                            "thickness": 2,
                            "strokeColor": None,
                            "colorRange":
                            {
                                "name": "Global Warming",
                                "type": "sequential",
                                "category": "Uber",
                                "colors":
                                [
                                    "#5A1846",
                                    "#900C3F",
                                    "#C70039",
                                    "#E3611C",
                                    "#F1920E",
                                    "#FFC300"
                                ]
                            },
                            "strokeColorRange":
                            {
                                "name": "Global Warming",
                                "type": "sequential",
                                "category": "Uber",
                                "colors":
                                [
                                    "#5A1846",
                                    "#900C3F",
                                    "#C70039",
                                    "#E3611C",
                                    "#F1920E",
                                    "#FFC300"
                                ]
                            },
                            "radiusRange":
                            [
                                0,
                                50
                            ],
                            "filled": True
                        },
                        "hidden": False,
                        "textLabel":
                        [
                            {
                                "field": None,
                                "color":
                                [
                                    255,
                                    255,
                                    255
                                ],
                                "size": 18,
                                "offset":
                                [
                                    0,
                                    0
                                ],
                                "anchor": "start",
                                "alignment": "center"
                            }
                        ]
                    },
                    "visualChannels":
                    {
                        "colorField":
                        {
                            "name": "COUNTYFP",
                            "type": "integer"
                        },
                        "colorScale": "quantile",
                        "strokeColorField": None,
                        "strokeColorScale": "quantile",
                        "sizeField": None,
                        "sizeScale": "linear"
                    }
                },
                {
                    "id": "nevr2z3",
                    "type": "geojson",
                    "config":
                    {
                        "dataId": "30tsioqw",
                        "label": "merged",
                        "color":
                        [
                            221,
                            163,
                            124
                        ],
                        "highlightColor":
                        [
                            252,
                            242,
                            26,
                            255
                        ],
                        "columns":
                        {
                            "geojson": "_geojson"
                        },
                        "isVisible": True,
                        "visConfig":
                        {
                            "opacity": 0.73,
                            "strokeOpacity": 0.8,
                            "thickness": 0,
                            "strokeColor":
                            [
                                255,
                                254,
                                230
                            ],
                            "colorRange":
                            {
                                "name": "ColorBrewer YlGn-6",
                                "type": "sequential",
                                "category": "ColorBrewer",
                                "colors":
                                [
                                    "#ffffcc",
                                    "#d9f0a3",
                                    "#addd8e",
                                    "#78c679",
                                    "#31a354",
                                    "#006837"
                                ]
                            },
                            "strokeColorRange":
                            {
                                "name": "Global Warming",
                                "type": "sequential",
                                "category": "Uber",
                                "colors":
                                [
                                    "#5A1846",
                                    "#900C3F",
                                    "#C70039",
                                    "#E3611C",
                                    "#F1920E",
                                    "#FFC300"
                                ]
                            },
                            "radius": 10,
                            "sizeRange":
                            [
                                0,
                                10
                            ],
                            "radiusRange":
                            [
                                0,
                                50
                            ],
                            "heightRange":
                            [
                                0,
                                500
                            ],
                            "elevationScale": 1.9,
                            "enableElevationZoomFactor": True,
                            "stroked": True,
                            "filled": True,
                            "enable3d": True,
                            "wireframe": False
                        },
                        "hidden": False,
                        "textLabel":
                        [
                            {
                                "field": None,
                                "color":
                                [
                                    255,
                                    255,
                                    255
                                ],
                                "size": 18,
                                "offset":
                                [
                                    0,
                                    0
                                ],
                                "anchor": "start",
                                "alignment": "center"
                            }
                        ]
                    },
                    "visualChannels":
                    {
                        "colorField":
                        {
                            "name": "tree_equity_score",
                            "type": "integer"
                        },
                        "colorScale": "quantile",
                        "strokeColorField": None,
                        "strokeColorScale": "quantile",
                        "sizeField": None,
                        "sizeScale": "linear",
                        "heightField":
                        {
                            "name": "tree_equity_score",
                            "type": "integer"
                        },
                        "heightScale": "log",
                        "radiusField": None,
                        "radiusScale": "linear"
                    }
                },
                {
                    "id": "y2rg9q",
                    "type": "hexagon",
                    "config":
                    {
                        "dataId": "30tsioqw",
                        "label": "new layer",
                        "color":
                        [
                            221,
                            178,
                            124
                        ],
                        "highlightColor":
                        [
                            252,
                            242,
                            26,
                            255
                        ],
                        "columns":
                        {
                            "lat": "INTPTLAT",
                            "lng": "INTPTLON"
                        },
                        "isVisible": False,
                        "visConfig":
                        {
                            "opacity": 0.8,
                            "worldUnitSize": 1,
                            "resolution": 8,
                            "colorRange":
                            {
                                "name": "ColorBrewer YlGn-6",
                                "type": "sequential",
                                "category": "ColorBrewer",
                                "colors":
                                [
                                    "#ffffcc",
                                    "#d9f0a3",
                                    "#addd8e",
                                    "#78c679",
                                    "#31a354",
                                    "#006837"
                                ]
                            },
                            "coverage": 0.55,
                            "sizeRange":
                            [
                                0,
                                500
                            ],
                            "percentile":
                            [
                                0,
                                100
                            ],
                            "elevationPercentile":
                            [
                                0,
                                100
                            ],
                            "elevationScale": 31.2,
                            "enableElevationZoomFactor": True,
                            "colorAggregation": "count",
                            "sizeAggregation": "average",
                            "enable3d": True
                        },
                        "hidden": False,
                        "textLabel":
                        [
                            {
                                "field": None,
                                "color":
                                [
                                    255,
                                    255,
                                    255
                                ],
                                "size": 18,
                                "offset":
                                [
                                    0,
                                    0
                                ],
                                "anchor": "start",
                                "alignment": "center"
                            }
                        ]
                    },
                    "visualChannels":
                    {
                        "colorField": None,
                        "colorScale": "quantile",
                        "sizeField":
                        {
                            "name": "tree_equity_score",
                            "type": "integer"
                        },
                        "sizeScale": "linear"
                    }
                }
            ],
            "interactionConfig":
            {
                "tooltip":
                {
                    "fieldsToShow":
                    {
                        "30tsioqw":
                        [
                            {
                                "name": "TRACTCE",
                                "format": None
                            },
                            {
                                "name": "BLKGRPCE",
                                "format": None
                            },
                            {
                                "name": "poc_percent",
                                "format": None
                            },
                            {
                                "name": "total_population",
                                "format": None
                            },
                            {
                                "name": "tree_canopy_gap",
                                "format": None
                            },
                            {
                                "name": "tree_equity_score",
                                "format": None
                            },
                            {
                                "name": "senior_percent",
                                "format": None
                            },
                            {
                                "name": "temperature_normalized",
                                "format": None
                            },
                            {
                                "name": "tree_canopy",
                                "format": None
                            }
                        ]
                    },
                    "compareMode": True,
                    "compareType": "absolute",
                    "enabled": True
                },
                "brush":
                {
                    "size": 8.8,
                    "enabled": False
                },
                "geocoder":
                {
                    "enabled": False
                },
                "coordinate":
                {
                    "enabled": False
                }
            },
            "layerBlending": "normal",
            "splitMaps":
            [],
            "animationConfig":
            {
                "currentTime": None,
                "speed": 1
            }
        },
        "mapState":
        {
            "bearing": 0,
            "dragRotate": False,
            "latitude": 33.61918722243666,
            "longitude": -112.22739107393414,
            "pitch": 0,
            "zoom": 9.011383136384884,
            "isSplit": False
        },
        "mapStyle":
        {
            "styleType": "dark",
            "topLayerGroups":
            {},
            "visibleLayerGroups":
            {
                "label": True,
                "road": True,
                "border": False,
                "building": True,
                "water": True,
                "land": True,
                "3d building": False
            },
            "threeDBuildingColor":
            [
                9.665468314072013,
                17.18305478057247,
                31.1442867897876
            ],
            "mapStyles":
            {}
        }
    }
}

# %%
map1 = KeplerGl(height=600, width=800, data={'merged':az_gjson},config=config)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/jupyter_client/session.py:716: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)

# %%
map1
# Out:
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': 'rtbxsn', 'type': '…
